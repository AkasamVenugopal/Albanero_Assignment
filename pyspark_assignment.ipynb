# %%
dataset=spark.read.csv("/FileStore/tables/annual_enterprise_survey_2021_financial_year_provisional_csv-3.csv",header=True)
# Out:
#   File "<command-3698513540034169>", line 2
#     import pyspark.sql import function as F
#                        ^
# SyntaxError: invalid syntax

# %%
display(dataset)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dataset.count()
# Out:
# Out[3]: 41715

# %%
dataset.show()
# Out:
# +----+---------------------------+--------------------+--------------------+------------------+-------------+--------------------+--------------------+---------+----------------------+
# |Year|Industry_aggregation_NZSIOC|Industry_code_NZSIOC|Industry_name_NZSIOC|             Units|Variable_code|       Variable_name|   Variable_category|    Value|Industry_code_ANZSIC06|
# +----+---------------------------+--------------------+--------------------+------------------+-------------+--------------------+--------------------+---------+----------------------+
# |2021|                    Level 1|               99999|      All industries|Dollars (millions)|          H01|        Total income|Financial perform...| 7,57,504|  ANZSIC06 division...|
# |2021|                    Level 1|               99999|      All industries|Dollars (millions)|          H04|Sales, government...|Financial perform...| 6,74,890|  ANZSIC06 division...|
# ...

# %%
dataset.head()
# Out:
# Out[8]: Row(Year='2021', Industry_aggregation_NZSIOC='Level 1', Industry_code_NZSIOC='99999', Industry_name_NZSIOC='All industries', Units='Dollars (millions)', Variable_code='H01', Variable_name='Total income', Variable_category='Financial performance', Value='7,57,504', Industry_code_ANZSIC06='ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)')

# %%
dataset.count()
# Out:
# Out[9]: 41715

# %%
data=spark.read.option("nullValue","null").csv("/FileStore/tables/annual_enterprise_survey_2021_financial_year_provisional_csv-3.csv",header=True)
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(data.filter("Year is null").count())
# Out:
# 0

# %%
display(data.filter("Industry_aggregation_NZSIOC is null").count())
# Out:
# 0

# %%
display(data.filter("Industry_code_NZSIOC is null").count())
# Out:
# 0

# %%
display(data.filter("Industry_name_NZSIOC is null").count())
# Out:
# 0

# %%
display(data.filter("Units is null").count())
# Out:
# 0

# %%
display(data.filter("Variable_code is null").count())
# Out:
# 0

# %%
display(data.filter("Variable_name is null").count())
# Out:
# 0

# %%
display(data.filter("Industry_code_ANZSIC06 is null").count())
# Out:
# 0

# %%
display(data.filter("value is null").count())
# Out:
# 0
